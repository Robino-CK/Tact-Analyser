# %%
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import librosa.display
import IPython.display as ipd
import pickle
import numpy as np
y, sr = librosa.load(librosa.ex('choice'), duration=10)

fig, ax = plt.subplots(nrows=3, sharex=True)
# erste Grafik
librosa.display.waveshow(y, sr=sr, ax=ax[0])

ax[0].set(title='Envelope view, mono')

ax[0].label_outer()
#zweite
y, sr = librosa.load(librosa.ex('choice', hq=True), mono=False, duration=10)

librosa.display.waveshow(y, sr=sr, ax=ax[1])

ax[1].set(title='Envelope view, stereo')

ax[1].label_outer()
# dritte
y, sr = librosa.load(librosa.ex('choice'), duration=10)

y_harm, y_perc = librosa.effects.hpss(y)

librosa.display.waveshow(y_harm, sr=sr, alpha=0.5, ax=ax[2], label='Harmonic')

librosa.display.waveshow(y_perc, sr=sr, color='r', alpha=0.5, ax=ax[2], label='Percussive')

ax[2].set(title='Multiple waveforms')

ax[2].legend()
# Out:
# Downloading file 'admiralbob77_-_Choice_-_Drum-bass.hq.ogg' from 'https://librosa.org/data/audio/admiralbob77_-_Choice_-_Drum-bass.hq.ogg' to 'C:\Users\robin\AppData\Local\librosa\librosa\Cache'.
